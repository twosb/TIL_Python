# %% [markdown]
# ##### 셀레니움을 이용하여 네이버 IT/과학 기사의 10 페이지 까지의 최신 제목 리스트를 크롤링하세요.
# - http://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=105

# %% [markdown]
# ### NAVER.COM IT/Science News Scraping by using Selenium.

# %%
from selenium import webdriver
import time

# %%
article_list = []
def article_Scraping():
    driver = webdriver.Chrome()
    for i in range(1, 11):
        driver.get("http://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=" + str(i))
        time.sleep(1)
        articles = driver.find_elements_by_css_selector('#section_body > ul > li > dl > dt > a')
        for article in articles:
            if article.text == "동영상기사":
                pass
            elif len(article.text) != 0:
                article_list.append(article.text)                
    driver.quit()
    for article in article_list:
        print(article)

article_Scraping()
# Out:
# 폴 크루그먼 "한국 경제도 보복무역 전쟁에 노출"
# [국제]“LG V40, 퀸터플 카메라 품는다”
# LG그룹, 4세대 경영 '구광모 대표이사' 체제 가동
# 강제참석 같지만 회식 근로시간 X, 체육대회 O···기준은
# HPE·삼성전자, CPU 의존도 낮춘 100배 빠른 '메모리 중심 컴퓨팅' 2년내 상용화
# 졸음이 오는 이유, 드디어 밝혀졌다
# "생산성 높였더니 ‘워라밸’이 따라왔다"
# 日탐사선 하야부사2, 3년반 만에 목표지점 도착…32억㎞ 여행
# “우주정책 지나치게 R&D 중심... 우주산업 키워 국가 성장동력화해야”
# 삼성·LGD, 대형 OLED 사업 전환 박차
# 카카오M, 한류기획사 3곳 투자...“연예·제작·광고 다 한다”
# 빗썸 해킹 원인 됐나…"외주 직원PC 침해"
# 중저가 외산폰의 역습, 통할까
# 발전소·공항 등 표적 '망 분리 무력화' 사이버 공격 발견
# 웹젠, 7월부터 자율출근제 시행…포괄임금제 폐지
# 화웨이 "내년 9월 5G폰 출시"…5G 장비 이어 단말기도 '눈독'
# 일본 연구팀, '졸음의 정체' 마침내 규명
# 웹젠, 자율출근제 시행…포괄임금제 폐지
# '포스트 리니지' 찾는 엔씨…신작 라인업에 2종 추가
# 달아오르는 월드컵 열기…'피파온라인4'서도 후끈
# [기획]먹는 물 위생 끝판왕, LG 퓨리케어 슬림 정수기
# 웹젠, 자율출근제 도입하고 포괄 임금제 폐지
# 네이버, 동반성장지수 평가 2년 연속 ‘최우수’ 등급
# [와우! 과학] 지구상에서 가장 추운 지역의 최저 온도는?
# 가민 '어프로치 Z80' 국내 출시… “GPS·레이저 결합해 골프 거리 측정”
# 네이버뉴스 어떻게 달라지나 보니…
# 피앤피시큐어, 올해 300억원 목표..내년 코스닥 간다
# 삼성전자, 이미지센서 신기술 '아이소셀 플러스' 발표
# 스타트업, ‘컬러’에 주목하다
# 기업 성장하려면, 무심한 듯 충성하는 고양이 전략 따르라
# KT, 29일 '삼성전자 갤럭시진' 단독 출시
# "5G 미리보자" 인산인해…카트로 사람 실어나르는 상하이
# HPE, 엣지컴퓨팅 '승부수'…4년간 4조 투입
# 중앙재난방송협의회, 재난방송 효율화·책임성 강화 논의
# "우주개발 정부 중심 탈피해야"…'우주혁신 성장 토론회'
# ‘SAS 바이야(SAS Viya)' 등 빅데이터 분석 플랫폼 각광
# 보스코인 대표 "기술-비즈니스 연계, 올해 보여줄 것"
# 정용진표 펀스토어 '삐에로쑈핑' 공개...쇼핑 신세계 열다
# 남방큰돌고래는 빙하기가 괴로워
# KT&G '릴'과 '핏', 판매처 전국 확대
# 최태원·조현아 연관 검색어 ‘삭제’…왜?
# 배틀그라운드 모바일, 매출 순위 다시 급상승
# 네덜란드-캐나다, 블록체인으로 여권없는 여행 가능해진다
# [블록체in 네덜란드③] 네덜란드에서 본 한국 블록체인의 가능성
# [퓨처ICT포럼] LG유플러스 유필계 부사장 "세계 통신사들이 한국 5G시장 지켜봐"
# “덕질은 다음카페에서"…다음, 공식 팬카페 전용 기능 오픈
# 우체국 ‘당일특급’ 철도운송 지역 늘린다
# KT, 중국 상하이서 5G 기술 선보인다..국내 통신사 유일
# AI시대, 소프트웨어에 밀렸던 '하드웨어'의 부활
# [MWC상하이] 황창규 KT 회장 “5G는 국가경쟁…中 속도, 예상 뛰어넘는 진전”
# 재난망 입찰 임박…통신사, 수주 경쟁 ‘점화’
# [현장] 세계 최대 동영상 축제, '비드콘 2018'을 가다
# 삼성전자, 카메라 감도 높인 이미지센서 신기술 발표
# 日 인공지능 AI 아나운서 개발..“25개 언어 구사, 재난방송에 활용”
# 관제예산 부족·근무시간 단축…‘이중고’에 시름하는 보안업계
# [이슈+] 숙박 O2O 맞아?…야놀자·여기어때, 레저 사업 진출 '경쟁'
# "화웨이 5G장비 쓸 거냐"…KT 황창규 '묵묵부답'
# 네이버, 신규 검색광고 사업자에 최대 10만원 광고비 지원
# 황창규 KT 회장 “中 5G 속도 빠르다…국가 차원 중요한 시기”
# 모바일 게임 후속작, 전작 인기 넘보다
# 한콘진, '뉴콘텐츠센터' 개관...4차 산업혁명 이끌 콘텐츠 기업 육성
# 페이스북 메신저 사용자, 10대서 증가세···점유율 두 자릿수 육박
# 네이버, 신규 검색광고 사업자에 최대 10만원 광고비 지원
# [주52시간 끝없는 논란]ICT업계 "보완책 환영…범위 더 넓혀야"
# SK텔레콤·KT, 텔레콤 아시아 어워드 수상
# KT, 이동전화 번호 재사용 금지
# [IT리뷰-넷기어 R6080] 멋진 디자인에 담긴 초고속 무선 네트워크
# 페이스북 메신저 사용자, 10대서 증가세…점유율 10%대 육박
# 변재일 의원 "케이블TV, 3년간 뭐했나?…합산규제 재제정 반대"
# 韓·日 합작 이미지센서 등장…삼성전자 ‘아이소셀 플러스’
# 지구 최저기온은 영하 98도…남극점 인근 동부 고원
# 중국, 실리콘밸리 '두뇌 사냥' 열중…미국은 비자제한 검토
# [ICT 명품인재 양성사업]포스텍 송영운 군, 자율 주행 자전거 기술 개발
# 황창규 "5G는 국가간 경쟁…KT가 5G 리더십 이끌겠다"
# [게임 상반기 결산] IP기반 모바일게임 강세
# 삼성電, 이미지센서 신기술 '아이소셀 플러스' 발표
# [미래기업포커스]유티플러스 "글로벌 승부 가능한 중견 개발사"
# '한·중 고위급 기업인 대화' 출범, 오는 29일 중국 베이징서 첫 회의
# 돼지 각막 이식받은 원숭이 눈 407일째 '정상' 유지
# 페이스북, 암호화폐 광고 전면금지 철회
# 황창규 “5G, 이미 국가 경쟁…中, 예상 뛰어넘는 진전”
# 통신3사·네이버·삼성SDS·LGCNS, 동반성장지수 '최우수'
# 게임펍, '신무월: 디바인' 사전예약자 30만명 돌파
# ‘카카오드라이버’ 27일부터 대리운전비 현금결제도 가능
# CJ ENM, 허민회 대표 단독체제..."미디어융복합 신사업 박차"
# 데이터 백업 시장, 클라우드 '부상'
# 거대 소행성 베스타, 지구 접근…7월 중순 맨눈 관찰 가능
# SKT·KT 5G 경쟁력 통했다…아시아 '최우수'선정
# 오픈소스 악용한 '도넛 랜섬웨어' 주의
# 확달라진 산업IoT용 DB '마크베이스' 내달 나온다
# "지니야~시켜줘"…AI스피커 주문 음식 1위는?
# 한류스타 핑크퐁, 제주항공 타고 하늘길 난다
# 아이폰6s, 인도서 생산…중고가 시장 공략
# [다이노+] 공룡은 ‘메롱’ 못한다…영화서 본 공룡 혀는 가짜
# KT 고객, 해지한 휴대전화 번호 29일간 사용 못 한다
# SKT-KT, “5G 기술 우리가 최고”
# 야놀자-여기어때, 액티비티 동시 출격… 시장 선점 신경전
# 수산시장 바가지 ‘퇴출’… 시세정보 스타트업, 32억 투자 유치
# 삼성바이오로직스, 日 바이오엑스포 참가
# KT, 다음달부터 해지 휴대폰 번호 재사용 29일간 제한
# 네이버노조 "ICT업종, 특별연장 근로허용 반대"
# LG 프리미엄 TV 갤러리 앱에 여행 콘텐츠 추가
# [MWCS 2018]한국시장을 잡아라…화웨이 5G전시 총력전
# [기획②] 디지털금융 외치지만…“금융IT 인력이 부족하다”
# [IT서비스업 미래는?②] 위기 자초한 IT서비스업계?
# SK텔레콤, 아시아 최우수 이통사로 선정..5G 성과
# [아하! 우주] 또 지구촌 민폐?…中 우주실험실 ‘톈궁-2’도 추락하나
# 개인 노리던 O2O, ‘가족형 서비스’로 진화
# KT, 다음달 2일부터 '이동전화 번호 재사용' 제한
# 트리플, "올 여름 해외여행 오사카 1위, 다낭 2위"
# 기가지니로 제일 많이 시킨 음식 1위 '치킨'
# 올 여름 해외여행지 1위 오사카…2위는 다낭
# ‘AI 윤리, 인력 양성’… 구글 AI 컨퍼런스가 남긴 숙제
# SK텔레콤, 5G 주파수 ‘만족’…기술·서비스 경쟁 박차
# ‘다시 액션게임인가’ 카카오게임즈-액션스퀘어 시험대 오른다
# 카카오택시 택시호출 1주일동안 5회 취소하면 24시간 이용제한
# 배달의민족, 배달비 결제 메뉴 추가…유료화 확산되나
# AI, 바둑에 이어 게임에서도 인간에 승리할까
# 아시아나IDT, 개인용 전기차 공유 서비스 추진
# 레진코믹스 서비스 5주년 기념 코인 10만 명한테 쏜다
# JOLED, 2020년 유기 EL 디스플레이 양산
# SKT, 2018 아시아 최우수 이통사 선정
# SK텔레콤, '텔레콤 아시아 어워드' 최우수 이통사 선정
# KT, 5G로 ‘텔레콤 아시아 어워드’ 수상
# '릴리안 생리대' 검색어, "언론보도 없다"며 내린 네이버
# 카톡이 지배한 모바일 메신저… 한국인 사용시간 94% 차지
# SKT, 아시아 최우수 이통사로 선정
# 페이스북, 무선 인터넷 공급용 드론 개발 중단
# 삼성·LG전자, 美·유럽 매체 TV 평가 1위 휩쓸어
# 채혈부터 검사까지...혈액 자동 분석기 등장
# 진화한 5G 신기술 격돌…내년 상용화 앞두고 탐색전
# 페북은 왜 '암호화폐 광고' 다시 허용하나
# 합산규제 폐지…유료방송 시장 ‘지각변동’ 신호탄
# 굳건한 카카오톡 점유율 94%…10대 페북 메신저 사용↑
# 동영상 광고, 2명중 1명 효과 있어..브랜드 이미지↑
# 밍치궈 예상 올 하반기 애플 신제품은?
# 클라우드 서열 4위로 떠오른 '알리바바'
# 삼성, 'QLED TV 매직스크린' 디자인 공모전 개최
# 韓 기상청 슈퍼컴 순위 75위…작년 57위서 대폭 하락
# "그래핀 이용해 DNA 분석할 수 있다" 美 연구팀 주장
# "中 블록체인, 금융과 B2B 중심으로 진화"
# "네이버, 재벌총수 일가 연관검색어 임의로 삭제"
# KISO, “네이버 대선기간 검색어 조작 없었다”
# 야놀자, ‘레저·액티비티 예약’ 7월3일 오픈
# '5G 선점 경쟁' MWC 상하이 개막…"화웨이 장비 채택하나"
# 非 MMORPG 신작들 잇따라 ‘출격’…순위 변화 꾀할까
# "네이버, 일부 그룹 총수 일가 연관 검색어 임의로 삭제"
# 중국 정부 "AI 핵심 기술에 집중해 제조업과 융합"
# 초저온 전자현미경이 포착한 지카 바이러스 실제 구조
# ‘온난화 최대 피해국’ 몽골에 기상기술 전수
# 라지 베리 우버이츠 아태 총괄 "1년만에 50% 망하는 식당, 기술로 살릴 것"
# [스페이스]펑크 안나는 우주타이어
# ‘삼재’에 흔들리는 유료방송 업계…규제 일몰·구조조정·넷플릭스까지
# 현실의 모습 투영돼 있는 게임 속의 난민들
# [MWC 상하이] "5G 미래 발견" 27일 개막
# [CEO] 두달새 또 찾아온 ‘위기’
# ③욕심과 모순을 넘어 SK 홈앤서비스 '거대한 실험'은 계속된다
# ②비정규직 노동조건 개선됐지만..민노총은 당기순익 2배이상 요구
# ①민주노총 과격 투쟁에 ‘비정규직 정규직화’ 발목 잡힐라
# 亞~'대구청년'의 인디게임에 반하다
# 수퍼컴 보유… 중국 206대, 미국 124대
# 애플, iOS 12 퍼블릭 베타버전 배포…"백업받고 시험해보길"
# 남극 진출 30년, 무너지는 얼음 대륙
# 첫 장맛비부터 국지성 폭우…내일 충청·남부 주의!
# 네이버, ‘최태원’·‘조현아’ 연관 검색어 삭제…왜?
# 내일 장마전선 남하, 최고 200mm 비…국지성호우 주의
# 장마전선 남하…내일 남부 집중호우 주의
# SK텔레콤, 포스텍과 5G 신기술 공동 연구
# 이상원 바이오기술평가학회장 "바이오산업 경쟁력 키우려면 기술평가 제대로 해야"
# 540조 세계 최대 스마트시티 '네옴' 어떻게 조성되나
# 권영수 LGU+ 부회장, MWC상하이 “ 참석-> 불참 -> 참석”...왜?
# 팀 쿡 "애플에도 많은 이민자 있어…그들을 옹호하고 싶어"
# 엑사랩, 글로벌 컨퍼런스 '2018 블록체인 세계대회' 참가…블록체인 기술명가 입증
# 마크로젠, 코스닥대상 시상식서 ‘최우수투명경영상’
# 최태원 "기업, 사회·경제적 가치 동시 추구해야"
# 문 정부 과기정책 속도… 국민생활 관련 연구비 늘린다
# LSD테크 고성능서버, CPU 사용 최소화… 성능 1.5배 ↑
# 모니터랩 AISVA, SSL 트래픽 암·복호화 처리 최적
# KT 기가지니, 생활편의 향상 초점… 스마트홈 토탈서비스 제공
# 빠르게 확산 중인 포시에스 전자문서, 활용 분야 무궁무진
# 씨게이트 엑소스 7E8 4TB, 일반자기기록에 200만 시간 무고장시간 지원
# 삼성SDS-델EMC, 클라우드 공략 손잡았다
# LG전자 G7 ThinQ, 충격 등 14개 부문 테스트 통과 … 내구성 탁월
# 어드밴텍케이알 POC-W213L, 제약·식음료 제조 위생관리 특화
# 지티원 체인지플로우, 애플리케이션 개발부터 버전 관리까지 원스톱
# 가온아이 이지워크스페이스, 포스트잇 붙이듯 업무계획 공유
# "통신요금 신고제 폐지땐 자율적 경쟁 촉진"
# 여름철 타이어 관리팁… 2시간 운전후 20분 쉬어주세요
# "북 ICT 수준 상당… 방송·통신, 남북교류 중요역할"
# CJ 오쇼핑 - E&M 합병법인 출범, 유료방송시장 M&A 촉발 신호탄
# 헬스케어 특위, 6대 헬스케어 프로젝트 추진
# “구글, AI무기 개발 불참 원칙 정했다”
# 바닷물로 담수 만들 때 나오는 폐수 30% 줄였다
# 구글 인공지능 수장의 숙제..."공정한 AI 위해 노력해야"
# “데이터 패러다임의 전환”…2020년까지 10조원 시장 키운다
# 네이버, 재벌 총수일가 연관검색어 절차 없이 지웠다
# “카이스트에서도 AI 프로젝트 비중은 5%뿐”
# ‘가명정보’ 연구목적 활용 어디까지…
# 고개 숙인 프리미엄폰...'G7 씽큐'도 판매 저조
# [2018 상반기 인기상품]고객만족-롯데정보통신 '다차로 하이패스'
